# %%
import pandas as pd
import yahoo_scrape as scrape
import yahoo_sql as ysql

# %%
companyData = pd.read_excel('C:\\Users\\chris\\OneDrive\\Programmering\\Python\\Jupyter notebooks\\tickers.xlsx')
tickers = companyData.Ticker
sql = ysql.fundamentals()

cnxn, cursor = sql.connect()
for index, tick in enumerate(tickers):
    try:
        print(f'{index} out of {len(tickers)}: ')
        shopify_stats = scrape.fundamentals(tick)
        table_list = shopify_stats.scrape()
        table_list = shopify_stats.labelTables(table_list)
        if len(table_list[0]) > 0: sql.merge(table_list[0], cnxn, cursor) #i.e. holds any data
        print('')
    except:
        print(f'Could not fetch data for {tick}')
        pass

cnxn.close()
# Out:
# l: https://finance.yahoo.com/quote/NETM-B.ST/key-statistics?p=NETM-B.ST
# SQL-merge done!
#
# 538 out of 692:
# Scraping NEXAM.ST using url: https://finance.yahoo.com/quote/NEXAM.ST/key-statistics?p=NEXAM.ST
# SQL-merge done!
#
# 539 out of 692:
# Scraping NFGAB.ST using url: https://finance.yahoo.com/quote/NFGAB.ST/key-statistics?p=NFGAB.ST
# SQL-merge done!
#
# 540 out of 692:
# Scraping NICO.ST using url: https://finance.yahoo.com/quote/NICO.ST/key-statistics?p=NICO.ST
# SQL-merge done!
#
# 541 out of 692:
# Scraping NILS.ST using url: https://finance.yahoo.com/quote/NILS.ST/key-statistics?p=NILS.ST
# SQL-merge done!
#
# 542 out of 692:
# Scraping NIO.ST using url: https://finance.yahoo.com/quote/NIO.ST/key-statistics?p=NIO.ST
# SQL-merge done!
#
# 543 out of 692:
# Scraping NITRO.ST using url: https://finance.yahoo.com/quote/NITRO.ST/key-statistics?p=NITRO.ST
# SQL-merge done!
#
# 544 out of 692:
# Scraping NJOB.ST using url: https://finance.yahoo.com/quote/NJOB.ST/key-statistics?p=NJOB.ST
# SQL-merge done!
#
# 545 out of 692:
# Scraping NLAB.ST using url: https://finance.yahoo.com/quote/NLAB.ST/key-statistics?p=NLAB.ST
# SQL-merge done!
#
# 546 out of 692:
# Scraping NNH.ST using url: https://finance.yahoo.com/quote/NNH.ST/key-statistics?p=NNH.ST
# SQL-merge done!
#
# 547 out of 692:
# Scraping NXTMS.ST using url: https://finance.yahoo.com/quote/NXTMS.ST/key-statistics?p=NXTMS.ST
# SQL-merge done!
#
# 548 out of 692:
# Scraping OBAB.ST using url: https://finance.yahoo.com/quote/OBAB.ST/key-statistics?p=OBAB.ST
# SQL-merge done!
#
# 549 out of 692:
# Scraping OBOYA-B.ST using url: https://finance.yahoo.com/quote/OBOYA-B.ST/key-statistics?p=OBOYA-B.ST
# SQL-merge done!
#
# 550 out of 692:
# Scraping ORGC.ST using url: https://finance.yahoo.com/quote/ORGC.ST/key-statistics?p=ORGC.ST
# SQL-merge done!
#
# 551 out of 692:
# Scraping OV.ST using url: https://finance.yahoo.com/quote/OV.ST/key-statistics?p=OV.ST
# SQL-merge done!
#
# 552 out of 692:
# Scraping OVZON.ST using url: https://finance.yahoo.com/quote/OVZON.ST/key-statistics?p=OVZON.ST
# SQL-merge done!
#
# 553 out of 692:
# Scraping PAPI.ST using url: https://finance.yahoo.com/quote/PAPI.ST/key-statistics?p=PAPI.ST
# SQL-merge done!
#
# 554 out of 692:
# Scraping PAX.ST using url: https://finance.yahoo.com/quote/PAX.ST/key-statistics?p=PAX.ST
# SQL-merge done!
#
# 555 out of 692:
# Scraping PCAT.ST using url: https://finance.yahoo.com/quote/PCAT.ST/key-statistics?p=PCAT.ST
# SQL-merge done!
#
# 556 out of 692:
# Scraping PCELL.ST using url: https://finance.yahoo.com/quote/PCELL.ST/key-statistics?p=PCELL.ST
# SQL-merge done!
#
# 557 out of 692:
# Scraping PCOM-B.ST using url: https://finance.yahoo.com/quote/PCOM-B.ST/key-statistics?p=PCOM-B.ST
# SQL-merge done!
#
# 558 out of 692:
# Scraping PDX.ST using url: https://finance.yahoo.com/quote/PDX.ST/key-statistics?p=PDX.ST
# SQL-merge done!
#
# 559 out of 692:
# Scraping PEGRO-PREF.ST using url: https://finance.yahoo.com/quote/PEGRO-PREF.ST/key-statistics?p=PEGRO-PREF.ST
# SQL-merge done!
#
# 560 out of 692:
# Scraping PIEZO.ST using url: https://finance.yahoo.com/quote/PIEZO.ST/key-statistics?p=PIEZO.ST
# SQL-merge done!
#
# 561 out of 692:
# Scraping PLED.ST using url: https://finance.yahoo.com/quote/PLED.ST/key-statistics?p=PLED.ST
# SQL-merge done!
#
# 562 out of 692:
# Scraping POLY.ST using url: https://finance.yahoo.com/quote/POLY.ST/key-statistics?p=POLY.ST
# SQL-merge done!
#
# 563 out of 692:
# Scraping POLYG.ST using url: https://finance.yahoo.com/quote/POLYG.ST/key-statistics?p=POLYG.ST
# SQL-merge done!
#
# 564 out of 692:
# Scraping PRCO-B.ST using url: https://finance.yahoo.com/quote/PRCO-B.ST/key-statistics?p=PRCO-B.ST
# SQL-merge done!
#
# 565 out of 692:
# Scraping PRIME.ST using url: https://finance.yahoo.com/quote/PRIME.ST/key-statistics?p=PRIME.ST
# SQL-merge done!
#
# 566 out of 692:
# Scraping PRIME-PREF-B.ST using url: https://finance.yahoo.com/quote/PRIME-PREF-B.ST/key-statistics?p=PRIME-PREF-B.ST
#
# 567 out of 692:
# Scraping PROMO.ST using url: https://finance.yahoo.com/quote/PROMO.ST/key-statistics?p=PROMO.ST
# SQL-merge done!
#
# 568 out of 692:
# Scraping QUART.ST using url: https://finance.yahoo.com/quote/QUART.ST/key-statistics?p=QUART.ST
# SQL-merge done!
#
# 569 out of 692:
# Scraping QUART-PREF.ST using url: https://finance.yahoo.com/quote/QUART-PREF.ST/key-statistics?p=QUART-PREF.ST
#
# 570 out of 692:
# Scraping RAKE.ST using url: https://finance.yahoo.com/quote/RAKE.ST/key-statistics?p=RAKE.ST
# SQL-merge done!
#
# 571 out of 692:
# Scraping REALFI.ST using url: https://finance.yahoo.com/quote/REALFI.ST/key-statistics?p=REALFI.ST
# SQL-merge done!
#
# 572 out of 692:
# Scraping REDS.ST using url: https://finance.yahoo.com/quote/REDS.ST/key-statistics?p=REDS.ST
# SQL-merge done!
#
# 573 out of 692:
# Scraping RLS.ST using url: https://finance.yahoo.com/quote/RLS.ST/key-statistics?p=RLS.ST
# SQL-merge done!
#
# 574 out of 692:
# Scraping RPLAN.ST using url: https://finance.yahoo.com/quote/RPLAN.ST/key-statistics?p=RPLAN.ST
# SQL-merge done!
#
# 575 out of 692:
# Scraping S2M.ST using url: https://finance.yahoo.com/quote/S2M.ST/key-statistics?p=S2M.ST
# SQL-merge done!
#
# 576 out of 692:
# Scraping SALT-B.ST using url: https://finance.yahoo.com/quote/SALT-B.ST/key-statistics?p=SALT-B.ST
# SQL-merge done!
#
# 577 out of 692:
# Scraping SAPIAB.ST using url: https://finance.yahoo.com/quote/SAPIAB.ST/key-statistics?p=SAPIAB.ST
# SQL-merge done!
#
# 578 out of 692:
# Scraping SAVOS.ST using url: https://finance.yahoo.com/quote/SAVOS.ST/key-statistics?p=SAVOS.ST
# SQL-merge done!
#
# 579 out of 692:
# Scraping SAXG.ST using url: https://finance.yahoo.com/quote/SAXG.ST/key-statistics?p=SAXG.ST
# SQL-merge done!
#
# 580 out of 692:
# Scraping SBB-B.ST using url: https://finance.yahoo.com/quote/SBB-B.ST/key-statistics?p=SBB-B.ST
# SQL-merge done!
#
# 581 out of 692:
# Scraping SBB-D.ST using url: https://finance.yahoo.com/quote/SBB-D.ST/key-statistics?p=SBB-D.ST
# SQL-merge done!
#
# 582 out of 692:
# Scraping SBB-PREF.ST using url: https://finance.yahoo.com/quote/SBB-PREF.ST/key-statistics?p=SBB-PREF.ST
#
# 583 out of 692:
# Scraping SBOK.ST using url: https://finance.yahoo.com/quote/SBOK.ST/key-statistics?p=SBOK.ST
# SQL-merge done!
#
# 584 out of 692:
# Scraping SCIB.ST using url: https://finance.yahoo.com/quote/SCIB.ST/key-statistics?p=SCIB.ST
# SQL-merge done!
#
# 585 out of 692:
# Scraping SCOUT.ST using url: https://finance.yahoo.com/quote/SCOUT.ST/key-statistics?p=SCOUT.ST
# SQL-merge done!
#
# 586 out of 692:
# Scraping SDIP-B.ST using url: https://finance.yahoo.com/quote/SDIP-B.ST/key-statistics?p=SDIP-B.ST
# SQL-merge done!
#
# 587 out of 692:
# Scraping SDIP-PREF.ST using url: https://finance.yahoo.com/quote/SDIP-PREF.ST/key-statistics?p=SDIP-PREF.ST
# SQL-merge done!
#
# 588 out of 692:
# Scraping SDOS.ST using url: https://finance.yahoo.com/quote/SDOS.ST/key-statistics?p=SDOS.ST
# SQL-merge done!
#
# 589 out of 692:
# Scraping SDS.ST using url: https://finance.yahoo.com/quote/SDS.ST/key-statistics?p=SDS.ST
# SQL-merge done!
#
# 590 out of 692:
# Scraping SECARE.ST using url: https://finance.yahoo.com/quote/SECARE.ST/key-statistics?p=SECARE.ST
# SQL-merge done!
#
# 591 out of 692:
# Scraping SECI.ST using url: https://finance.yahoo.com/quote/SECI.ST/key-statistics?p=SECI.ST
# SQL-merge done!
#
# 592 out of 692:
# Scraping SEDANA.ST using url: https://finance.yahoo.com/quote/SEDANA.ST/key-statistics?p=SEDANA.ST
# SQL-merge done!
#
# 593 out of 692:
# Scraping SENZA.ST using url: https://finance.yahoo.com/quote/SENZA.ST/key-statistics?p=SENZA.ST
# SQL-merge done!
#
# 594 out of 692:
# Scraping SERT.ST using url: https://finance.yahoo.com/quote/SERT.ST/key-statistics?p=SERT.ST
# SQL-merge done!
#
# 595 out of 692:
# Scraping SES.ST using url: https://finance.yahoo.com/quote/SES.ST/key-statistics?p=SES.ST
# SQL-merge done!
#
# 596 out of 692:
# Scraping SEYE.ST using url: https://finance.yahoo.com/quote/SEYE.ST/key-statistics?p=SEYE.ST
# SQL-merge done!
#
# 597 out of 692:
# Scraping SEZI.ST using url: https://finance.yahoo.com/quote/SEZI.ST/key-statistics?p=SEZI.ST
# SQL-merge done!
#
# 598 out of 692:
# Scraping SF.ST using url: https://finance.yahoo.com/quote/SF.ST/key-statistics?p=SF.ST
# SQL-merge done!
#
# 599 out of 692:
# Scraping SIMRIS-B.ST using url: https://finance.yahoo.com/quote/SIMRIS-B.ST/key-statistics?p=SIMRIS-B.ST
# SQL-merge done!
#
# 600 out of 692:
# Scraping SIVE.ST using url: https://finance.yahoo.com/quote/SIVE.ST/key-statistics?p=SIVE.ST
# SQL-merge done!
#
# 601 out of 692:
# Scraping SJR-B.ST using url: https://finance.yahoo.com/quote/SJR-B.ST/key-statistics?p=SJR-B.ST
# SQL-merge done!
#
# 602 out of 692:
# Scraping SKMO.ST using url: https://finance.yahoo.com/quote/SKMO.ST/key-statistics?p=SKMO.ST
# SQL-merge done!
#
# 603 out of 692:
# Scraping SNM.ST using url: https://finance.yahoo.com/quote/SNM.ST/key-statistics?p=SNM.ST
# SQL-merge done!
#
# 604 out of 692:
# Scraping SOLNA.ST using url: https://finance.yahoo.com/quote/SOLNA.ST/key-statistics?p=SOLNA.ST
# SQL-merge done!
#
# 605 out of 692:
# Scraping SOLT.ST using url: https://finance.yahoo.com/quote/SOLT.ST/key-statistics?p=SOLT.ST
# SQL-merge done!
#
# 606 out of 692:
# Scraping SONE.ST using url: https://finance.yahoo.com/quote/SONE.ST/key-statistics?p=SONE.ST
# SQL-merge done!
#
# 607 out of 692:
# Scraping SPEC.ST using url: https://finance.yahoo.com/quote/SPEC.ST/key-statistics?p=SPEC.ST
# SQL-merge done!
#
# 608 out of 692:
# Scraping SPIFF.ST using url: https://finance.yahoo.com/quote/SPIFF.ST/key-statistics?p=SPIFF.ST
# SQL-merge done!
#
# 609 out of 692:
# Scraping SPRINT.ST using url: https://finance.yahoo.com/quote/SPRINT.ST/key-statistics?p=SPRINT.ST
# SQL-merge done!
#
# 610 out of 692:
# Scraping STIL.ST using url: https://finance.yahoo.com/quote/STIL.ST/key-statistics?p=STIL.ST
# SQL-merge done!
#
# 611 out of 692:
# Scraping STORY-B.ST using url: https://finance.yahoo.com/quote/STORY-B.ST/key-statistics?p=STORY-B.ST
# SQL-merge done!
#
# 612 out of 692:
# Scraping STW.ST using url: https://finance.yahoo.com/quote/STW.ST/key-statistics?p=STW.ST
# SQL-merge done!
#
# 613 out of 692:
# Scraping SUS.ST using url: https://finance.yahoo.com/quote/SUS.ST/key-statistics?p=SUS.ST
# SQL-merge done!
#
# 614 out of 692:
# Scraping TAGM-B.ST using url: https://finance.yahoo.com/quote/TAGM-B.ST/key-statistics?p=TAGM-B.ST
# SQL-merge done!
#
# 615 out of 692:
# Scraping TALK.ST using url: https://finance.yahoo.com/quote/TALK.ST/key-statistics?p=TALK.ST
# SQL-merge done!
#
# 616 out of 692:
# Scraping TANGI.ST using url: https://finance.yahoo.com/quote/TANGI.ST/key-statistics?p=TANGI.ST
# SQL-merge done!
#
# 617 out of 692:
# Scraping TCC.ST using url: https://finance.yahoo.com/quote/TCC.ST/key-statistics?p=TCC.ST
#
# 618 out of 692:
# Scraping TCT.ST using url: https://finance.yahoo.com/quote/TCT.ST/key-statistics?p=TCT.ST
# SQL-merge done!
#
# 619 out of 692:
# Scraping TERRNT-B.ST using url: https://finance.yahoo.com/quote/TERRNT-B.ST/key-statistics?p=TERRNT-B.ST
# SQL-merge done!
#
# 620 out of 692:
# Scraping TORSAB.ST using url: https://finance.yahoo.com/quote/TORSAB.ST/key-statistics?p=TORSAB.ST
# SQL-merge done!
#
# 621 out of 692:
# Scraping TRANS.ST using url: https://finance.yahoo.com/quote/TRANS.ST/key-statistics?p=TRANS.ST
# SQL-merge done!
#
# 622 out of 692:
# Scraping TRIAN-B.ST using url: https://finance.yahoo.com/quote/TRIAN-B.ST/key-statistics?p=TRIAN-B.ST
# SQL-merge done!
#
# 623 out of 692:
# Scraping TSEC.ST using url: https://finance.yahoo.com/quote/TSEC.ST/key-statistics?p=TSEC.ST
# SQL-merge done!
#
# 624 out of 692:
# Scraping UNIBAP.ST using url: https://finance.yahoo.com/quote/UNIBAP.ST/key-statistics?p=UNIBAP.ST
# SQL-merge done!
#
# 625 out of 692:
# Scraping URBIT.ST using url: https://finance.yahoo.com/quote/URBIT.ST/key-statistics?p=URBIT.ST
# SQL-merge done!
#
# 626 out of 692:
# Scraping UTG.ST using url: https://finance.yahoo.com/quote/UTG.ST/key-statistics?p=UTG.ST
# SQL-merge done!
#
# 627 out of 692:
# Scraping VEMF-SDB.ST using url: https://finance.yahoo.com/quote/VEMF-SDB.ST/key-statistics?p=VEMF-SDB.ST
# SQL-merge done!
#
# 628 out of 692:
# Scraping VERI.ST using url: https://finance.yahoo.com/quote/VERI.ST/key-statistics?p=VERI.ST
# SQL-merge done!
#
# 629 out of 692:
# Scraping VICO.ST using url: https://finance.yahoo.com/quote/VICO.ST/key-statistics?p=VICO.ST
# SQL-merge done!
#
# 630 out of 692:
# Scraping WAYS.ST using url: https://finance.yahoo.com/quote/WAYS.ST/key-statistics?p=WAYS.ST
# SQL-merge done!
#
# 631 out of 692:
# Scraping WESC.ST using url: https://finance.yahoo.com/quote/WESC.ST/key-statistics?p=WESC.ST
# SQL-merge done!
#
# 632 out of 692:
# Scraping WPAY.ST using url: https://finance.yahoo.com/quote/WPAY.ST/key-statistics?p=WPAY.ST
# SQL-merge done!
#
# 633 out of 692:
# Scraping XBRANE.ST using url: https://finance.yahoo.com/quote/XBRANE.ST/key-statistics?p=XBRANE.ST
# SQL-merge done!
#
# 634 out of 692:
# Scraping XINT.ST using url: https://finance.yahoo.com/quote/XINT.ST/key-statistics?p=XINT.ST
# SQL-merge done!
#
# 635 out of 692:
# Scraping XMR.ST using url: https://finance.yahoo.com/quote/XMR.ST/key-statistics?p=XMR.ST
# SQL-merge done!
#
# 636 out of 692:
# Scraping XSPRAY.ST using url: https://finance.yahoo.com/quote/XSPRAY.ST/key-statistics?p=XSPRAY.ST
# SQL-merge done!
#
# 637 out of 692:
# Scraping ZAPLOX.ST using url: https://finance.yahoo.com/quote/ZAPLOX.ST/key-statistics?p=ZAPLOX.ST
# SQL-merge done!
#
# 638 out of 692:
# Scraping ZUTEC.ST using url: https://finance.yahoo.com/quote/ZUTEC.ST/key-statistics?p=ZUTEC.ST
# SQL-merge done!
#
# 639 out of 692:
# Scraping ZZ-B.ST using url: https://finance.yahoo.com/quote/ZZ-B.ST/key-statistics?p=ZZ-B.ST
# SQL-merge done!
#
# 640 out of 692:
# Scraping AAP-B.ST using url: https://finance.yahoo.com/quote/AAP-B.ST/key-statistics?p=AAP-B.ST
# SQL-merge done!
#
# 641 out of 692:
# Scraping ACARIX.ST using url: https://finance.yahoo.com/quote/ACARIX.ST/key-statistics?p=ACARIX.ST
# SQL-merge done!
#
# 642 out of 692:
# Scraping ADVE.ST using url: https://finance.yahoo.com/quote/ADVE.ST/key-statistics?p=ADVE.ST
# SQL-merge done!
#
# 643 out of 692:
# Scraping AGES-B.ST using url: https://finance.yahoo.com/quote/AGES-B.ST/key-statistics?p=AGES-B.ST
# SQL-merge done!
#
# 644 out of 692:
# Scraping ALZCUR.ST using url: https://finance.yahoo.com/quote/ALZCUR.ST/key-statistics?p=ALZCUR.ST
# SQL-merge done!
#
# 645 out of 692:
# Scraping AMAST.ST using url: https://finance.yahoo.com/quote/AMAST.ST/key-statistics?p=AMAST.ST
# SQL-merge done!
#
# 646 out of 692:
# Scraping AMAST-PREF.ST using url: https://finance.yahoo.com/quote/AMAST-PREF.ST/key-statistics?p=AMAST-PREF.ST
#
# 647 out of 692:
# Scraping ASPIRE.ST using url: https://finance.yahoo.com/quote/ASPIRE.ST/key-statistics?p=ASPIRE.ST
# SQL-merge done!
#
# 648 out of 692:
# Scraping AUR.ST using url: https://finance.yahoo.com/quote/AUR.ST/key-statistics?p=AUR.ST
# SQL-merge done!
#
# 649 out of 692:
# Scraping AVEN.ST using url: https://finance.yahoo.com/quote/AVEN.ST/key-statistics?p=AVEN.ST
# SQL-merge done!
#
# 650 out of 692:
# Scraping BIOVIC-B.ST using url: https://finance.yahoo.com/quote/BIOVIC-B.ST/key-statistics?p=BIOVIC-B.ST
# SQL-merge done!
#
# 651 out of 692:
# Scraping BYGGP.ST using url: https://finance.yahoo.com/quote/BYGGP.ST/key-statistics?p=BYGGP.ST
# SQL-merge done!
#
# 652 out of 692:
# Scraping CAG.ST using url: https://finance.yahoo.com/quote/CAG.ST/key-statistics?p=CAG.ST
# SQL-merge done!
#
# 653 out of 692:
# Scraping CLIME-B.ST using url: https://finance.yahoo.com/quote/CLIME-B.ST/key-statistics?p=CLIME-B.ST
# SQL-merge done!
#
# 654 out of 692:
# Scraping DEVP-B.ST using url: https://finance.yahoo.com/quote/DEVP-B.ST/key-statistics?p=DEVP-B.ST
# SQL-merge done!
#
# 655 out of 692:
# Scraping DIST.ST using url: https://finance.yahoo.com/quote/DIST.ST/key-statistics?p=DIST.ST
# SQL-merge done!
#
# 656 out of 692:
# Scraping DRIL.ST using url: https://finance.yahoo.com/quote/DRIL.ST/key-statistics?p=DRIL.ST
# SQL-merge done!
#
# 657 out of 692:
# Scraping GOMX.ST using url: https://finance.yahoo.com/quote/GOMX.ST/key-statistics?p=GOMX.ST
# SQL-merge done!
#
# 658 out of 692:
# Scraping GPG-PREF.ST using url: https://finance.yahoo.com/quote/GPG-PREF.ST/key-statistics?p=GPG-PREF.ST
#
# 659 out of 692:
# Scraping HANZA.ST using url: https://finance.yahoo.com/quote/HANZA.ST/key-statistics?p=HANZA.ST
# SQL-merge done!
#
# 660 out of 692:
# Scraping HEIM-PREF.ST using url: https://finance.yahoo.com/quote/HEIM-PREF.ST/key-statistics?p=HEIM-PREF.ST
#
# 661 out of 692:
# Scraping IRLAB-A.ST using url: https://finance.yahoo.com/quote/IRLAB-A.ST/key-statistics?p=IRLAB-A.ST
# SQL-merge done!
#
# 662 out of 692:
# Scraping IRRAS.ST using url: https://finance.yahoo.com/quote/IRRAS.ST/key-statistics?p=IRRAS.ST
# SQL-merge done!
#
# 663 out of 692:
# Scraping ISOFOL.ST using url: https://finance.yahoo.com/quote/ISOFOL.ST/key-statistics?p=ISOFOL.ST
# SQL-merge done!
#
# 664 out of 692:
# Scraping JETPAK.ST using url: https://finance.yahoo.com/quote/JETPAK.ST/key-statistics?p=JETPAK.ST
# SQL-merge done!
#
# 665 out of 692:
# Scraping K2A-PREF.ST using url: https://finance.yahoo.com/quote/K2A-PREF.ST/key-statistics?p=K2A-PREF.ST
#
# 666 out of 692:
# Scraping KAN.ST using url: https://finance.yahoo.com/quote/KAN.ST/key-statistics?p=KAN.ST
# SQL-merge done!
#
# 667 out of 692:
# Scraping LAUR.ST using url: https://finance.yahoo.com/quote/LAUR.ST/key-statistics?p=LAUR.ST
# SQL-merge done!
#
# 668 out of 692:
# Scraping LYKO-A.ST using url: https://finance.yahoo.com/quote/LYKO-A.ST/key-statistics?p=LYKO-A.ST
# SQL-merge done!
#
# 669 out of 692:
# Scraping MAGI.ST using url: https://finance.yahoo.com/quote/MAGI.ST/key-statistics?p=MAGI.ST
# SQL-merge done!
#
# 670 out of 692:
# Scraping MANG.ST using url: https://finance.yahoo.com/quote/MANG.ST/key-statistics?p=MANG.ST
# SQL-merge done!
#
# 671 out of 692:
# Scraping NETG.ST using url: https://finance.yahoo.com/quote/NETG.ST/key-statistics?p=NETG.ST
# SQL-merge done!
#
# 672 out of 692:
# Scraping NEXAM.ST using url: https://finance.yahoo.com/quote/NEXAM.ST/key-statistics?p=NEXAM.ST
# SQL-merge done!
#
# 673 out of 692:
# Scraping OVZON.ST using url: https://finance.yahoo.com/quote/OVZON.ST/key-statistics?p=OVZON.ST
# SQL-merge done!
#
# 674 out of 692:
# Scraping PDX.ST using url: https://finance.yahoo.com/quote/PDX.ST/key-statistics?p=PDX.ST
# SQL-merge done!
#
# 675 out of 692:
# Scraping PEGRO-PREF.ST using url: https://finance.yahoo.com/quote/PEGRO-PREF.ST/key-statistics?p=PEGRO-PREF.ST
# SQL-merge done!
#
# 676 out of 692:
# Scraping PRCO-B.ST using url: https://finance.yahoo.com/quote/PRCO-B.ST/key-statistics?p=PRCO-B.ST
# SQL-merge done!
#
# 677 out of 692:
# Scraping PRIME.ST using url: https://finance.yahoo.com/quote/PRIME.ST/key-statistics?p=PRIME.ST
# SQL-merge done!
#
# 678 out of 692:
# Scraping PRIME-PREF-B.ST using url: https://finance.yahoo.com/quote/PRIME-PREF-B.ST/key-statistics?p=PRIME-PREF-B.ST
#
# 679 out of 692:
# Scraping RAKE.ST using url: https://finance.yahoo.com/quote/RAKE.ST/key-statistics?p=RAKE.ST
# SQL-merge done!
#
# 680 out of 692:
# Scraping SALT-B.ST using url: https://finance.yahoo.com/quote/SALT-B.ST/key-statistics?p=SALT-B.ST
# SQL-merge done!
#
# 681 out of 692:
# Scraping SBB-B.ST using url: https://finance.yahoo.com/quote/SBB-B.ST/key-statistics?p=SBB-B.ST
# SQL-merge done!
#
# 682 out of 692:
# Scraping SBB-D.ST using url: https://finance.yahoo.com/quote/SBB-D.ST/key-statistics?p=SBB-D.ST
# SQL-merge done!
#
# 683 out of 692:
# Scraping SBB-PREF.ST using url: https://finance.yahoo.com/quote/SBB-PREF.ST/key-statistics?p=SBB-PREF.ST
#
# 684 out of 692:
# Scraping SDIP-B.ST using url: https://finance.yahoo.com/quote/SDIP-B.ST/key-statistics?p=SDIP-B.ST
# SQL-merge done!
#
# 685 out of 692:
# Scraping SDIP-PREF.ST using url: https://finance.yahoo.com/quote/SDIP-PREF.ST/key-statistics?p=SDIP-PREF.ST
# SQL-merge done!
#
# 686 out of 692:
# Scraping SDS.ST using url: https://finance.yahoo.com/quote/SDS.ST/key-statistics?p=SDS.ST
# SQL-merge done!
#
# 687 out of 692:
# Scraping SF.ST using url: https://finance.yahoo.com/quote/SF.ST/key-statistics?p=SF.ST
# SQL-merge done!
#
# 688 out of 692:
# Scraping SPRINT.ST using url: https://finance.yahoo.com/quote/SPRINT.ST/key-statistics?p=SPRINT.ST
# SQL-merge done!
#
# 689 out of 692:
# Scraping TERRNT-B.ST using url: https://finance.yahoo.com/quote/TERRNT-B.ST/key-statistics?p=TERRNT-B.ST
# SQL-merge done!
#
# 690 out of 692:
# Scraping TRIAN-B.ST using url: https://finance.yahoo.com/quote/TRIAN-B.ST/key-statistics?p=TRIAN-B.ST
# SQL-merge done!
#
# 691 out of 692:
# Scraping VERI.ST using url: https://finance.yahoo.com/quote/VERI.ST/key-statistics?p=VERI.ST
# SQL-merge done!
